# %% [markdown]
# <a href="https://colab.research.google.com/github/First-555/dataviz2025/blob/main/midterm2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ให้สืบหาฆาตรกร (10 คะแนน) และ ผู้บงการ (5 คะแนน) ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City โดยเริ่มจากการตรวจสอบ ข้อมูลคดีในไฟล์ crime_scene_report.csv

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/MyDrive/Data_Viz_2025/Data2' #set path --> folder and then join path เพื่อให้โค้ดrunได้ทุกที่

person_file_path = os.path.join(path,'person.csv')
interview_file_path = os.path.join(path,'interview.csv')
income_file_path = os.path.join(path,'income.csv')
get_fit_now_member_file_path = os.path.join(path,'get_fit_now_member.csv')
get_fit_now_check_in_file_path = os.path.join(path,'get_fit_now_check_in.csv')
facebook_event_checkin_file_path = os.path.join(path,'facebook_event_checkin.csv')
driver_license_file_path = os.path.join(path,'drivers_license.csv')
crime_scene_report_file_path = os.path.join(path,'crime_scene_report.csv')
print(person_file_path)
print(interview_file_path)
print(income_file_path)
print(get_fit_now_member_file_path)
print(get_fit_now_check_in_file_path)
print(facebook_event_checkin_file_path)
print(driver_license_file_path)
print(crime_scene_report_file_path)
# Out:
# /content/drive/MyDrive/Data_Viz_2025/Data2/person.csv
# /content/drive/MyDrive/Data_Viz_2025/Data2/interview.csv
# /content/drive/MyDrive/Data_Viz_2025/Data2/income.csv
# /content/drive/MyDrive/Data_Viz_2025/Data2/get_fit_now_member.csv
# /content/drive/MyDrive/Data_Viz_2025/Data2/get_fit_now_check_in.csv
# /content/drive/MyDrive/Data_Viz_2025/Data2/facebook_event_checkin.csv
# /content/drive/MyDrive/Data_Viz_2025/Data2/drivers_license.csv
# /content/drive/MyDrive/Data_Viz_2025/Data2/crime_scene_report.csv

# %%
person = pd.read_csv(person_file_path)
interview = pd.read_csv(interview_file_path)
income = pd.read_csv(income_file_path)
get_fit_now_member = pd.read_csv(get_fit_now_member_file_path)
get_fit_now_check_in = pd.read_csv(get_fit_now_check_in_file_path)
facebook_event_checkin = pd.read_csv(facebook_event_checkin_file_path)
driver_license = pd.read_csv(driver_license_file_path)
crime_scene_report = pd.read_csv(crime_scene_report_file_path)

# %% [markdown]
# # อ่านไฟล์ crime_scene_report.csv

# %%
crime_scene_report_df = pd.read_csv('/content/drive/MyDrive/Data_Viz_2025/Data2/crime_scene_report.csv')
display(crime_scene_report_df.head())
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#           city
# 0          NYC
# 1       Albany
# 2         Reno
# 3  Pandas City
# 4  Pandas City

# %% [markdown]
# ## เลือกเมือง Pandas city

# %%
pandas_city_crimes = crime_scene_report_df[crime_scene_report_df['city'] == 'Pandas City']
display(pandas_city_crimes)
# Out:
#           date     type                                        description  \
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# 7     20170712    theft  A lone hunter stalks the night, firing arrows ...
# 8     20170820    arson  Wield the Hammer of Sol with honor, Titan, it ...
# 9     20171110  robbery  The Gjallarhorn shoulder-mounted rocket system...
# 10    20180103  bribery  Apparently, Cayde thought it necessary to expo...
# 11    20180115  assault  Hamilton: Lee, do you yield? Burr: You shot hi...
# 12    20180115  assault                                   Report Not Found
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#              city
# 3     Pandas City
# 4     Pandas City
# 7     Pandas City
# 8     Pandas City
# 9     Pandas City
# 10    Pandas City
# 11    Pandas City
# 12    Pandas City
# 1227  Pandas City

# %% [markdown]
# ## เลือกเฉพาะคดี murder

# %%
pandas_city_murders = pandas_city_crimes[pandas_city_crimes['type'] == 'murder']
display(pandas_city_murders)
# Out:
#           date    type                                        description  \
# 3     20180215  murder                         REDACTED REDACTED REDACTED
# 4     20180215  murder  Someone killed the guard! He took an arrow to ...
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#              city
# 3     Pandas City
# 4     Pandas City
# 1227  Pandas City

# %% [markdown]
# ## วันที่ 15 มกราคม 2018

# %%
murder_on_20180115 = pandas_city_murders[pandas_city_murders['date'] == 20180115]
display(murder_on_20180115)
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#              city
# 1227  Pandas City

# %%
# คำอธิบาย ภาพจากกล้องวงจรปิดแสดงให้เห็นว่ามีพยาน 2 คน พยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบนถนน "Northwestern Dr" ส่วนพยานคนที่สองชื่อแอนนาเบล อาศัยอยู่ที่ไหนสักแห่งบนถนน "Franklin Ave"
# Out:
# 'Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".'

# %% [markdown]
# ## ตรวจสอบพยาน

# %% [markdown]
# ### พยานคนที่ 1

# %%
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
#address_street_name แค่ Northwestern Dr
northwestern_dr_residents = person[person.address_street_name == 'Northwestern Dr']
display(northwestern_dr_residents)
# Out:
#          id                  name  license_id  address_number  \
# 2     10010             Muoi Cary      385336             741
# 282   12711        Norman Apolito      667757             599
# 499   14887        Morty Schapiro      118009            4919
# 528   15171          Weldon Penso      336999             311
# 811   17729        Lasonya Wildey      439686            3824
# 904   18376              Josh Shi      653712            1091
# 1021  19420           Cody Schiel      890431            3524
# 1338  22239         Dusty Sigafus      710517            1125
# 1426  23044          Val Portlock      924989            3143
# 1522  23960  Kristopher Lagerberg      658777            1392
# 1686  25615         Olevia Morena      388477             812
# 1812  26758      Angelena Billman      942074             629
# 1981  28360        Rashad Cascone      924517            3212
# 2131  29608       Willetta Lurvey      800568            1028
# ...

# %%
#หาบ้านหลังสุดท้าย
last_house_number = person[person.address_street_name == 'Northwestern Dr']['address_number'].max()

# หา person ที่อยู่บ้านหลังสุดท้ายบนถนน Northwestern Dr
witness1 = person[(person.address_street_name == 'Northwestern Dr') & (person.address_number == last_house_number)]
witness1
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#            ssn
# 499  111564949

# %%
# หา id จากไฟล์ interview
interview_witness1 = interview[interview.person_id == 14887]
interview_witness1
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...

# %% [markdown]
# ### คำให้การของพยานคนที่ 1

# %% [markdown]
# I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
#  แปล ฉันได้ยินเสียงปืน แล้วก็เห็นผู้ชายคนหนึ่งวิ่งออกมา เขาถือกระเป๋า "Get Fit Now Gym" หมายเลขสมาชิกบนกระเป๋าขึ้นต้นด้วย "48Z" มีแต่สมาชิกระดับ Gold เท่านั้นที่จะมีกระเป๋าแบบนั้น ชายคนนั้นขึ้นรถที่มีป้ายทะเบียน "H42W"

# %%
# หาสมาชิก gold ที่มี id ขึ้นต้นด้วย '48Z' (เป็นผู้ต้องสงสัย)
get_fit_now_member[(get_fit_now_member.membership_status == 'gold') & (get_fit_now_member.id.str.startswith('48Z'))]
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# จากข้อมูลมีผู้ต้องสงสัย 1 คน คือ Jeremy Bowers	 เนื่องจาก Joe Germuska	สมัคร member หลังจกากเกิดคดี

# %%
# หารถที่ป้ายทะเบียนขึ้นต้นด้วย "H42W".
driver_license[driver_license.plate_number.str.startswith('H42W')]
# Out:
#          id  age  height eye_color hair_color  gender plate_number car_make  \
# 915  183779   21      65      blue     blonde  female       H42W0X   Toyota
#
#     car_model
# 915     Prius

# %% [markdown]
# ### พยานคนที่ 2

# %% [markdown]
# ชื่อ Annabel อาศัยอยู่ที่ไหนสักแห่งบนถนน "Franklin Ave"

# %%
#บนถนน Franklin Ave
northwestern_dr_residents = person[person.address_street_name =='Franklin Ave']
display(northwestern_dr_residents)
# Out:
#          id                 name  license_id  address_number  \
# 235   12207       Wilmer Wolever      509484             139
# 665   16371       Annabel Miller      490173             103
# 807   17683        Johnnie Schee      968887            1277
# 936   18651        Carleen Etoll      356746              22
# 1377  22636       Zachary Ybarbo      768359             785
# 1608  24737           Gema Nantz      273410            3968
# 2236  30654      Clarita Rickels      418084            2254
# 2427  32264       Shelby Dezeeuw      735415            1391
# 2584  33793         Amado Mattan      161915              99
# 2661  34592    Cordell Lindamood      592762            3657
# 2864  36328         Domenic Laun      971080            3809
# 2877  36400         Noe Pancoast      895755            3443
# 3009  37616     Katelyn Schwerin      430143             332
# 4086  46827         Bev Billiter      643591            2316
# ...

# %%
#หา name ที่ขึ้นต้นด้วย Annabel และ address_street_name คือ Franklin Ave
witness2  = person[(person.name.str.startswith('Annabel')) & (person.address_street_name == 'Franklin Ave')]
display(witness2 )
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
# หา id จากไฟล์ interview
interview_witness2 = interview[interview.person_id == 16371]
interview_witness2
# Out:
#       person_id                                         transcript
# 4989      16371  I saw the murder happen, and I recognized the ...
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_18.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# ...

# %% [markdown]
# ### คำให้การของพยานคนที่ 2

# %% [markdown]
# I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.
# แปล ฉันเห็นเหตุการณ์ฆาตกรรมเกิดขึ้น และฉันจำฆาตกรได้จากโรงยิมของฉันในขณะที่ฉันกำลังออกกำลังกายเมื่อวันที่ 9 มกราคมที่ผ่านมา

# %% [markdown]
# # ตรวจสอบผู้ต้องสงสัย

# %%
#ตรวจสอบการ checkin ของวันที่  20180109 ของ Jeremy Bowers
get_fit_now_check_in[(get_fit_now_check_in.check_in_date == 20180109) & (get_fit_now_check_in.membership_id == '48Z55')]
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 2701         48Z55       20180109           1530            1700

# %%
#ตรวจสอบการ checkin ของวันที่  20180109 ของ Joe Germuska
get_fit_now_check_in[(get_fit_now_check_in.check_in_date == 20180109) & (get_fit_now_check_in.membership_id == '48Z7A')]
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 2700         48Z7A       20180109           1600            1730

# %% [markdown]
# ## คำให้การของ 	Jeremy Bowers

# %%
interview_suspect1 = interview[interview.person_id == 67318]
interview_suspect1
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %% [markdown]
# ### I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.
# แปล ฉันถูกจ้างโดยผู้หญิงคนหนึ่งที่มีเงินมากมาย ฉันไม่รู้จักชื่อเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว) เธอมีผมสีแดงและขับรถ Tesla Model S ฉันรู้ว่าเธอไปคอนเสิร์ต SQL Symphony 3 ครั้งในเดือนธันวาคม 2017

# %%
driver_license
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
#เลือก heigth 65-67 และ hair_color คือ red gender คือ femalecar_make คือ Tesla car_model คือ Model S
suspect2_license = driver_license[
    (driver_license['height'].between(65, 67)) &
    (driver_license['hair_color'] == 'red') &
    (driver_license['gender'] == 'female') &
    (driver_license['car_make'] == 'Tesla') &
    (driver_license['car_model'] == 'Model S')
]
display(suspect2_license)
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 9078   Model S

# %% [markdown]
# # ผู้ต้องสงสัยว่าเป็นผู้ว่าจ้าง

# %% [markdown]
# ## จาก license_id

# %%
person[person.license_id == 202298]
# Out:
#          id              name  license_id  address_number address_street_name  \
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 9985  987756388

# %%
person[person.license_id == 291182]
# Out:
#          id           name  license_id  address_number address_street_name  \
# 8977  90700  Regina George      291182             332           Maple Ave
#
#             ssn
# 8977  337169072

# %%
person[person.license_id == 918773]
# Out:
#          id      name  license_id  address_number address_street_name  \
# 7664  78881  Red Korb      918773             107         Camerata Dr
#
#             ssn
# 7664  961388910

# %%
facebook_event_checkin
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
#เลือก event_name คือ SQL Symphony Concert
ql_symphony_checkins = facebook_event_checkin[facebook_event_checkin['event_name'] == 'SQL Symphony Concert']
display(sql_symphony_checkins)
# Out:
#        person_id  event_id            event_name      date
# 11         97207      1143  SQL Symphony Concert  20170322
# 12         97207      1143  SQL Symphony Concert  20180226
# 109        92433      1143  SQL Symphony Concert  20170821
# 110        92433      1143  SQL Symphony Concert  20180327
# 296        88952      1143  SQL Symphony Concert  20170918
# ...          ...       ...                   ...       ...
# 20003      24556      1143  SQL Symphony Concert  20171224
# 20006      99716      1143  SQL Symphony Concert  20171206
# 20007      99716      1143  SQL Symphony Concert  20171212
# 20008      99716      1143  SQL Symphony Concert  20171229
# 20010      67318      1143  SQL Symphony Concert  20171206
#
# [212 rows x 4 columns]

# %%
#ที่ date อยู่ในช่วง 20171201-20171231 3 ครั้ง
# Count the number of check-ins per person in December 2017
december_checkin_counts = december_2017_sql_checkins['person_id'].value_counts().reset_index()
december_checkin_counts.columns = ['person_id', 'checkin_count']

# Filter for persons who checked in exactly 3 times
suspect2_person_id = december_checkin_counts[december_checkin_counts['checkin_count'] == 3]
display(suspect2_person_id)
# Out:
#    person_id  checkin_count
# 0      24556              3
# 1      99716              3

# %% [markdown]
# ## คนที่ไปงานคอนเสิร์ต SQL Symphony 3 ครั้งในเดือนธันวาคม 2017

# %%
person[person.id == 24556]
# Out:
#          id         name  license_id  address_number address_street_name  \
# 1587  24556  Bryan Pardo      101191             703          Machine Ln
#
#             ssn
# 1587  816663882

# %%
person[person.id == 99716]
# Out:
#          id              name  license_id  address_number address_street_name  \
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 9985  987756388

# %% [markdown]
#  ## Miranda Priestly มี license_id ตรงกับ ผู้ต้องสงสัย คือ 202298

# %% [markdown]
# ### คำให้การของ Miranda Priestly

# %%
interview_suspect2 = interview[interview.person_id == 99716]
interview_suspect2
# Out:
# Empty DataFrame
# Columns: [person_id, transcript]
# Index: []

# %% [markdown]
# # สรุป

# %% [markdown]
# ## ฆาตกร คือ  Jeremy Bowers

# %% [markdown]
# ## ผู้บงกร คือ Miranda Priestly
